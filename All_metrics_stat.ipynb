# %%
import pandas as pd

# %%
file = "all_metrics_China.xlsx"
data = pd.read_excel(file)
data
# Out:
#        Column         Model       RMSE       MAE      MAPE
# 0     China_4  ARIMA(0,1,0)  13.713252  5.674497  1.155381
# 1     China_4  ARIMA(3,1,0)  13.706367  5.705097  1.162494
# 2    China_33  ARIMA(0,1,0)   2.312390  1.085762  1.564134
# 3    China_33  ARIMA(4,1,0)   2.295862  1.128112  1.618739
# 4   China_103  ARIMA(0,1,0)   4.367209  0.831434  2.022371
# 5   China_103  ARIMA(2,1,0)   4.375751  0.844506  2.074469
# 6   China_165  ARIMA(0,1,0)   2.505596  1.429179  2.426500
# 7   China_165  ARIMA(5,1,0)   2.521015  1.454150  2.467348
# 8   China_169  ARIMA(0,1,0)   2.521232  1.121289  2.116863
# 9   China_169  ARIMA(4,1,0)   2.509172  1.140320  2.151381
# 10  China_203  ARIMA(0,1,0)   4.993430  1.861668  1.730038
# 11  China_203  ARIMA(2,1,0)   5.016487  1.884243  1.753490
# 12  China_209  ARIMA(0,1,0)   2.197433  0.681365  0.916394
# 13  China_209  ARIMA(4,1,0)   2.202806  0.722506  0.964741
# 14  China_213  ARIMA(0,1,0)   3.264882  1.156064  1.555526
# ...

# %%
india = pd.read_excel("all_metrics_India.xlsx")
india
# Out:
#        Column         Model      RMSE       MAE      MAPE
# 0     India_8  ARIMA(0,1,0)  3.406503  0.911479  0.708860
# 1     India_8  ARIMA(3,1,0)  3.287592  0.935633  0.733865
# 2    India_36  ARIMA(0,1,0)  6.037686  2.505453  1.162368
# 3    India_36  ARIMA(3,1,0)  6.031486  2.533808  1.177177
# 4    India_40  ARIMA(0,1,0)  3.178347  1.051503  1.035072
# 5    India_40  ARIMA(5,1,0)  3.040389  1.128489  1.122832
# 6    India_67  ARIMA(0,1,0)  4.094624  1.099141  0.914847
# 7    India_67  ARIMA(4,1,0)  4.059374  1.219558  1.021187
# 8    India_69  ARIMA(0,1,0)  4.424356  1.640624  1.437665
# 9    India_69  ARIMA(4,1,0)  4.361479  1.723788  1.503875
# 10  India_124  ARIMA(0,1,0)  1.193408  0.532746  1.266775
# 11  India_124  ARIMA(3,1,0)  1.211618  0.548247  1.303734
# 12  India_136  ARIMA(0,1,0)  2.086588  0.951484  1.864115
# 13  India_136  ARIMA(3,1,0)  2.121765  0.994730  1.964283
# 14  India_153  ARIMA(0,1,0)  3.381848  1.249677  1.107660
# ...

# %%
c = []
for i in range(len(data["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": data["Column"][i],
                  "Модель": data["Model"][i + 1],
                  "Отношение RMSE": data["RMSE"][i + 1] / data["RMSE"][i],
                  "Отношение MAE": data["MAE"][i + 1] / data["MAE"][i],
                  "Отношение MAPE": data["MAPE"][i + 1] / data["MAPE"][i]
                 })
dfс = pd.DataFrame(c)
dfс
# Out:
#    Переменная        Модель  Отношение RMSE  Отношение MAE  Отношение MAPE
# 0     China_4  ARIMA(3,1,0)        0.999498       1.005393        1.006156
# 1    China_33  ARIMA(4,1,0)        0.992852       1.039005        1.034911
# 2   China_103  ARIMA(2,1,0)        1.001956       1.015722        1.025761
# 3   China_165  ARIMA(5,1,0)        1.006154       1.017473        1.016834
# 4   China_169  ARIMA(4,1,0)        0.995216       1.016972        1.016306
# 5   China_203  ARIMA(2,1,0)        1.004617       1.012126        1.013556
# 6   China_209  ARIMA(4,1,0)        1.002445       1.060380        1.052757
# 7   China_213  ARIMA(2,1,0)        1.005903       1.015783        1.016270
# 8   China_228  ARIMA(3,1,0)        1.011940       1.017828        1.016686
# 9   China_250  ARIMA(2,1,0)        0.995121       1.002259        1.001153
# 10  China_265  ARIMA(6,1,0)        1.002943       1.042194        1.046326

# %%
c = []
for i in range(len(india["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": india["Column"][i],
                  "Модель": india["Model"][i + 1],
                  "Отношение RMSE": india["RMSE"][i + 1] / india["RMSE"][i],
                  "Отношение MAE": india["MAE"][i + 1] / india["MAE"][i],
                  "Отношение MAPE": india["MAPE"][i + 1] / india["MAPE"][i]
                 })
dfi = pd.DataFrame(c)
dfi
# Out:
#    Переменная        Модель  Отношение RMSE  Отношение MAE  Отношение MAPE
# 0     India_8  ARIMA(3,1,0)        0.965093       1.026500        1.035275
# 1    India_36  ARIMA(3,1,0)        0.998973       1.011317        1.012741
# 2    India_40  ARIMA(5,1,0)        0.956594       1.073215        1.084786
# 3    India_67  ARIMA(4,1,0)        0.991391       1.109556        1.116239
# 4    India_69  ARIMA(4,1,0)        0.985788       1.050691        1.046054
# 5   India_124  ARIMA(3,1,0)        1.015259       1.029097        1.029176
# 6   India_136  ARIMA(3,1,0)        1.016858       1.045452        1.053735
# 7   India_153  ARIMA(6,1,0)        0.973650       1.066208        1.098948
# 8   India_160  ARIMA(3,1,0)        1.010154       1.029931        1.027493
# 9   India_172  ARIMA(4,1,0)        0.938192       1.049316        1.070628
# 10  India_199  ARIMA(6,1,0)        1.012183       1.098410        1.101365
# ...

# %%
######## ex

# %%
file = "ARIMA_ex_model_metrics_China.xlsx"
dataex = pd.read_excel(file)
dataex
# Out:
#        Column         Model       RMSE       MAE      MAPE
# 0     China_4  ARIMA(0,1,0)  13.713252  5.674497  1.155381
# 1     China_4  ARIMA(3,1,0)  13.959970  7.600103  1.605783
# 2    China_33  ARIMA(0,1,0)   2.312390  1.085762  1.564134
# 3    China_33  ARIMA(4,1,0)   2.293624  1.218552  1.775021
# 4   China_103  ARIMA(0,1,0)   4.367209  0.831434  2.022371
# 5   China_103  ARIMA(2,1,0)   4.392771  1.060946  2.551411
# 6   China_165  ARIMA(0,1,0)   2.505596  1.429179  2.426500
# 7   China_165  ARIMA(5,1,0)   2.390541  1.448198  2.537551
# 8   China_169  ARIMA(0,1,0)   2.521232  1.121289  2.116863
# 9   China_169  ARIMA(4,1,0)   2.485293  1.382164  2.643450
# 10  China_203  ARIMA(0,1,0)   4.993430  1.861668  1.730038
# 11  China_203  ARIMA(2,1,0)   5.075752  2.326855  2.261446
# 12  China_209  ARIMA(0,1,0)   2.197433  0.681365  0.916394
# 13  China_209  ARIMA(4,1,0)   2.215886  0.861118  1.156273
# 14  China_213  ARIMA(0,1,0)   3.264882  1.156064  1.555526
# ...

# %%
file = "ARIMA_ex_model_metrics_India.xlsx"
indiaex = pd.read_excel(file)
indiaex
# Out:
#        Column         Model      RMSE       MAE      MAPE
# 0     India_8  ARIMA(0,1,0)  3.406503  0.911479  0.708860
# 1     India_8  ARIMA(3,1,0)  3.282127  1.232370  1.041150
# 2    India_36  ARIMA(0,1,0)  6.037686  2.505453  1.162368
# 3    India_36  ARIMA(3,1,0)  5.624766  3.084162  1.504470
# 4    India_40  ARIMA(0,1,0)  3.178347  1.051503  1.035072
# 5    India_40  ARIMA(5,1,0)  3.051535  1.244382  1.280087
# 6    India_67  ARIMA(0,1,0)  4.094624  1.099141  0.914847
# 7    India_67  ARIMA(4,1,0)  4.086832  1.505461  1.324160
# 8    India_69  ARIMA(0,1,0)  4.424356  1.640624  1.437665
# 9    India_69  ARIMA(4,1,0)  4.357302  1.836904  1.631367
# 10  India_124  ARIMA(0,1,0)  1.193408  0.532746  1.266775
# 11  India_124  ARIMA(3,1,0)  1.154940  0.717825  1.791075
# 12  India_136  ARIMA(0,1,0)  2.086588  0.951484  1.864115
# 13  India_136  ARIMA(3,1,0)  2.161847  1.220368  2.595398
# 14  India_153  ARIMA(0,1,0)  3.381848  1.249677  1.107660
# ...

# %%
c = []
for i in range(len(dataex["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": dataex["Column"][i],
                  "Модель": dataex["Model"][i + 1],
                  "Отношение RMSE": dataex["RMSE"][i + 1] / dataex["RMSE"][i],
                  "Отношение MAE": dataex["MAE"][i + 1] / dataex["MAE"][i],
                  "Отношение MAPE": dataex["MAPE"][i + 1] / dataex["MAPE"][i]
                 })
dfcex = pd.DataFrame(c)
dfcex
# Out:
#    Переменная        Модель  Отношение RMSE  Отношение MAE  Отношение MAPE
# 0     China_4  ARIMA(3,1,0)        1.017991       1.339344        1.389829
# 1    China_33  ARIMA(4,1,0)        0.991884       1.122301        1.134827
# 2   China_103  ARIMA(2,1,0)        1.005853       1.276043        1.261594
# 3   China_165  ARIMA(5,1,0)        0.954081       1.013308        1.045766
# 4   China_169  ARIMA(4,1,0)        0.985745       1.232655        1.248758
# 5   China_203  ARIMA(2,1,0)        1.016486       1.249877        1.307166
# 6   China_209  ARIMA(4,1,0)        1.008397       1.263813        1.261763
# 7   China_213  ARIMA(2,1,0)        1.001859       1.199663        1.247499
# 8   China_228  ARIMA(3,1,0)        1.008914       1.253574        1.287337
# 9   China_250  ARIMA(2,1,0)        0.987109       1.037651        1.052218
# 10  China_265  ARIMA(6,1,0)        0.986225       1.153768        1.183462

# %%
c = []
for i in range(len(indiaex["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": indiaex["Column"][i],
                  "Модель": indiaex["Model"][i + 1],
                  "Отношение RMSE": indiaex["RMSE"][i + 1] / indiaex["RMSE"][i],
                  "Отношение MAE": indiaex["MAE"][i + 1] / indiaex["MAE"][i],
                  "Отношение MAPE": indiaex["MAPE"][i + 1] / indiaex["MAPE"][i]
                 })
dfiex = pd.DataFrame(c)
dfiex
# Out:
#    Переменная        Модель  Отношение RMSE  Отношение MAE  Отношение MAPE
# 0     India_8  ARIMA(3,1,0)        0.963489       1.352056        1.468767
# 1    India_36  ARIMA(3,1,0)        0.931610       1.230980        1.294315
# 2    India_40  ARIMA(5,1,0)        0.960101       1.183432        1.236713
# 3    India_67  ARIMA(4,1,0)        0.998097       1.369671        1.447412
# 4    India_69  ARIMA(4,1,0)        0.984844       1.119638        1.134734
# 5   India_124  ARIMA(3,1,0)        0.967766       1.347406        1.413886
# 6   India_136  ARIMA(3,1,0)        1.036068       1.282595        1.392295
# 7   India_153  ARIMA(6,1,0)        0.956762       1.178340        1.258618
# 8   India_160  ARIMA(3,1,0)        1.002146       1.180057        1.221515
# 9   India_172  ARIMA(4,1,0)        0.925325       1.127623        1.181801
# 10  India_199  ARIMA(6,1,0)        1.037882       1.454599        1.511513
# ...

# %%
#### intervals

# %%
file = "Interval_metrics_China.xlsx"
datai = pd.read_excel(file)
datai
# Out:
#                                Column                 Interval         Model  \
# 0     China_4_2010-01-01 - 2012-05-31  2010-01-01 - 2012-05-31  ARIMA(0,1,0)
# 1     China_4_2010-01-01 - 2012-05-31  2010-01-01 - 2012-05-31  ARIMA(3,1,0)
# 2     China_4_2012-05-31 - 2014-11-19  2012-05-31 - 2014-11-19  ARIMA(0,1,0)
# 3     China_4_2012-05-31 - 2014-11-19  2012-05-31 - 2014-11-19  ARIMA(3,1,0)
# 4     China_4_2014-11-19 - 2023-06-07  2014-11-19 - 2023-06-07  ARIMA(0,1,0)
# ..                                ...                      ...           ...
# 61  China_265_2013-04-02 - 2015-05-15  2013-04-02 - 2015-05-15  ARIMA(6,1,0)
# 62  China_265_2015-05-15 - 2016-12-05  2015-05-15 - 2016-12-05  ARIMA(0,1,0)
# 63  China_265_2015-05-15 - 2016-12-05  2015-05-15 - 2016-12-05  ARIMA(6,1,0)
# 64  China_265_2016-12-05 - 2023-06-07  2016-12-05 - 2023-06-07  ARIMA(0,1,0)
# 65  China_265_2016-12-05 - 2023-06-07  2016-12-05 - 2023-06-07  ARIMA(6,1,0)
#
#          RMSE        MAE      MAPE
# ...

# %%
file = "Interval_metrics_India.xlsx"
indiai = pd.read_excel(file)
indiai
# Out:
#                                Column                 Interval         Model  \
# 0     India_8_2010-01-01 - 2018-02-16  2010-01-01 - 2018-02-16  ARIMA(0,1,0)
# 1     India_8_2010-01-01 - 2018-02-16  2010-01-01 - 2018-02-16  ARIMA(3,1,0)
# 2     India_8_2018-02-16 - 2020-03-17  2018-02-16 - 2020-03-17  ARIMA(0,1,0)
# 3     India_8_2018-02-16 - 2020-03-17  2018-02-16 - 2020-03-17  ARIMA(3,1,0)
# 4     India_8_2020-03-17 - 2023-11-02  2020-03-17 - 2023-11-02  ARIMA(0,1,0)
# ..                                ...                      ...           ...
# 75  India_220_2010-01-01 - 2012-05-31  2010-01-01 - 2012-05-31  ARIMA(3,1,0)
# 76  India_220_2012-05-31 - 2014-11-06  2012-05-31 - 2014-11-06  ARIMA(0,1,0)
# 77  India_220_2012-05-31 - 2014-11-06  2012-05-31 - 2014-11-06  ARIMA(3,1,0)
# 78  India_220_2014-11-06 - 2023-06-07  2014-11-06 - 2023-06-07  ARIMA(0,1,0)
# 79  India_220_2014-11-06 - 2023-06-07  2014-11-06 - 2023-06-07  ARIMA(3,1,0)
#
#          RMSE       MAE      MAPE
# ...

# %%
datai["Column"][64][:-24]
# Out:
# 'China_265'

# %%
c = []
for i in range(len(datai["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": datai["Column"][i][:-24],
                  "Модель": datai["Model"][i + 1],
                  "Интервал": datai["Interval"][i],
                  "Отношение RMSE": datai["RMSE"][i + 1] / datai["RMSE"][i],
                  "Отношение MAE": datai["MAE"][i + 1] / datai["MAE"][i],
                  "Отношение MAPE": datai["MAPE"][i + 1] / datai["MAPE"][i]
                 })
dfci = pd.DataFrame(c)
dfci
# Out:
#    Переменная        Модель                 Интервал  Отношение RMSE  \
# 0     China_4  ARIMA(3,1,0)  2010-01-01 - 2012-05-31        1.005610
# 1     China_4  ARIMA(3,1,0)  2012-05-31 - 2014-11-19        1.000269
# 2     China_4  ARIMA(3,1,0)  2014-11-19 - 2023-06-07        0.971269
# 3    China_33  ARIMA(4,1,0)  2010-01-01 - 2013-12-09        0.967213
# 4    China_33  ARIMA(4,1,0)  2013-12-09 - 2016-01-19        1.037164
# 5    China_33  ARIMA(4,1,0)  2016-01-19 - 2024-01-18        1.001360
# 6   China_103  ARIMA(2,1,0)  2014-11-21 - 2015-10-14        1.011629
# 7   China_103  ARIMA(2,1,0)  2015-10-14 - 2023-04-17        1.001908
# 8   China_165  ARIMA(5,1,0)  2010-01-01 - 2013-06-18        0.989041
# 9   China_165  ARIMA(5,1,0)  2013-06-18 - 2020-03-05        1.002510
# 10  China_165  ARIMA(5,1,0)  2020-03-05 - 2024-01-18        1.022386
# 11  China_169  ARIMA(4,1,0)  2010-01-01 - 2014-09-23        1.021485
# 12  China_169  ARIMA(4,1,0)  2014-09-23 - 2021-04-08        0.986078
# ...

# %%
c = []
for i in range(len(indiai["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": indiai["Column"][i][:-24],
                  "Модель": indiai["Model"][i + 1],
                  "Интервал": indiai["Interval"][i],
                  "Отношение RMSE": indiai["RMSE"][i + 1] / indiai["RMSE"][i],
                  "Отношение MAE": indiai["MAE"][i + 1] / indiai["MAE"][i],
                  "Отношение MAPE": indiai["MAPE"][i + 1] / indiai["MAPE"][i]
                 })
dfii = pd.DataFrame(c)
dfii
# Out:
#    Переменная        Модель                 Интервал  Отношение RMSE  \
# 0     India_8  ARIMA(3,1,0)  2010-01-01 - 2018-02-16        0.997812
# 1     India_8  ARIMA(3,1,0)  2018-02-16 - 2020-03-17        0.850729
# 2     India_8  ARIMA(3,1,0)  2020-03-17 - 2023-11-02        1.087346
# 3    India_36  ARIMA(3,1,0)  2010-01-01 - 2012-05-31        1.000702
# 4    India_36  ARIMA(3,1,0)  2012-05-31 - 2014-09-23        1.004701
# 5    India_36  ARIMA(3,1,0)  2014-09-23 - 2023-06-07        0.971568
# 6    India_40  ARIMA(5,1,0)  2010-01-01 - 2013-01-04        1.015321
# 7    India_40  ARIMA(5,1,0)  2013-01-04 - 2021-04-15        0.929860
# 8    India_40  ARIMA(5,1,0)  2021-04-15 - 2024-01-18        1.037548
# 9    India_67  ARIMA(4,1,0)  2010-01-01 - 2012-05-30        0.971855
# 10   India_67  ARIMA(4,1,0)  2012-05-30 - 2020-03-10        0.978230
# 11   India_67  ARIMA(4,1,0)  2020-03-10 - 2024-01-18        1.022815
# 12   India_69  ARIMA(4,1,0)  2010-01-01 - 2012-01-23        0.981022
# ...

# %%
### intervals + ex

# %%
file = "ARIMA_ex_model_metrics_China_Intervals.xlsx"
dataiex = pd.read_excel(file)
dataiex
# Out:
#                                Column         Model       RMSE        MAE  \
# 0     China_4 2010-01-01 - 2012-05-31  ARIMA(0,1,0)  45.313395  33.415888
# 1     China_4 2010-01-01 - 2012-05-31  ARIMA(3,1,0)  43.057421  31.904953
# 2     China_4 2012-05-31 - 2014-11-19  ARIMA(0,1,0)  12.346916   7.700913
# 3     China_4 2012-05-31 - 2014-11-19  ARIMA(3,1,0)  13.045764   8.985674
# 4     China_4 2014-11-19 - 2023-06-07  ARIMA(0,1,0)   7.147675   3.745059
# ..                                ...           ...        ...        ...
# 61  China_265 2013-04-02 - 2015-05-15  ARIMA(6,1,0)  12.656106   7.970558
# 62  China_265 2015-05-15 - 2016-12-05  ARIMA(0,1,0)   9.117932   5.640288
# 63  China_265 2015-05-15 - 2016-12-05  ARIMA(6,1,0)   8.752163   5.582972
# 64  China_265 2016-12-05 - 2023-06-07  ARIMA(0,1,0)   4.657879   2.370884
# 65  China_265 2016-12-05 - 2023-06-07  ARIMA(6,1,0)   5.279617   3.436307
#
#         MAPE
# 0   2.463871
# 1   2.359775
# 2   1.356511
# 3   1.594519
# ...

# %%
c = []
for i in range(len(dataiex["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": dataiex["Column"][i][:-24],
                  "Модель": dataiex["Model"][i + 1],
                  "Интервал": dataiex["Column"][i][-23:],
                  "Отношение RMSE": dataiex["RMSE"][i + 1] / dataiex["RMSE"][i],
                  "Отношение MAE": dataiex["MAE"][i + 1] / dataiex["MAE"][i],
                  "Отношение MAPE": dataiex["MAPE"][i + 1] / dataiex["MAPE"][i]
                 })
dfciex = pd.DataFrame(c)
dfciex
# Out:
#    Переменная        Модель                 Интервал  Отношение RMSE  \
# 0     China_4  ARIMA(3,1,0)  2010-01-01 - 2012-05-31        0.950214
# 1     China_4  ARIMA(3,1,0)  2012-05-31 - 2014-11-19        1.056601
# 2     China_4  ARIMA(3,1,0)  2014-11-19 - 2023-06-07        1.059953
# 3    China_33  ARIMA(4,1,0)  2010-01-01 - 2013-12-09        0.970062
# 4    China_33  ARIMA(4,1,0)  2013-12-09 - 2016-01-19        1.011069
# 5    China_33  ARIMA(4,1,0)  2016-01-19 - 2024-01-18        1.003809
# 6   China_103  ARIMA(2,1,0)  2014-11-21 - 2015-10-14        0.992607
# 7   China_103  ARIMA(2,1,0)  2015-10-14 - 2023-04-17        1.005647
# 8   China_165  ARIMA(5,1,0)  2010-01-01 - 2013-06-18        0.934790
# 9   China_165  ARIMA(5,1,0)  2013-06-18 - 2020-03-05        0.928347
# 10  China_165  ARIMA(5,1,0)  2020-03-05 - 2024-01-18        0.977378
# 11  China_169  ARIMA(4,1,0)  2010-01-01 - 2014-09-23        0.999048
# 12  China_169  ARIMA(4,1,0)  2014-09-23 - 2021-04-08        0.937145
# ...

# %%
file = "ARIMA_ex_model_metrics_India_Intervals.xlsx"
indiaiex = pd.read_excel(file)
indiaiex
# Out:
#                                Column         Model       RMSE       MAE  \
# 0     India_8 2010-01-01 - 2018-02-16  ARIMA(0,1,0)   1.627262  0.678832
# 1     India_8 2010-01-01 - 2018-02-16  ARIMA(3,1,0)   1.677704  0.937107
# 2     India_8 2018-02-16 - 2020-03-17  ARIMA(0,1,0)   3.039522  1.327838
# 3     India_8 2018-02-16 - 2020-03-17  ARIMA(3,1,0)   2.613909  1.208324
# 4     India_8 2020-03-17 - 2023-11-02  ARIMA(0,1,0)   2.954978  0.395149
# ..                                ...           ...        ...       ...
# 75  India_220 2010-01-01 - 2012-05-31  ARIMA(1,1,0)  10.923066  7.841382
# 76  India_220 2012-05-31 - 2014-11-06  ARIMA(0,1,0)   3.359791  2.090278
# 77  India_220 2012-05-31 - 2014-11-06  ARIMA(1,1,0)   3.250028  2.268659
# 78  India_220 2014-11-06 - 2023-06-07  ARIMA(0,1,0)   1.860982  0.982940
# 79  India_220 2014-11-06 - 2023-06-07  ARIMA(1,1,0)   2.260861  1.594597
#
#         MAPE
# 0   0.386811
# 1   0.549508
# 2   1.291711
# 3   1.174765
# 4   0.349214
# ...

# %%
c = []
for i in range(len(indiaiex["Column"])):
    if i % 2 == 0:
        c.append({"Переменная": indiaiex["Column"][i][:-24],
                  "Модель": indiaiex["Model"][i + 1],
                  "Интервал": indiaiex["Column"][i][-23:],
                  "Отношение RMSE": indiaiex["RMSE"][i + 1] / indiaiex["RMSE"][i],
                  "Отношение MAE": indiaiex["MAE"][i + 1] / indiaiex["MAE"][i],
                  "Отношение MAPE": indiaiex["MAPE"][i + 1] / indiaiex["MAPE"][i]
                 })
dfiiex = pd.DataFrame(c)
dfiiex
# Out:
#    Переменная        Модель                 Интервал  Отношение RMSE  \
# 0     India_8  ARIMA(3,1,0)  2010-01-01 - 2018-02-16        1.030998
# 1     India_8  ARIMA(3,1,0)  2018-02-16 - 2020-03-17        0.859974
# 2     India_8  ARIMA(3,1,0)  2020-03-17 - 2023-11-02        1.118123
# 3    India_36  ARIMA(3,1,0)  2010-01-01 - 2012-05-31        0.970801
# 4    India_36  ARIMA(3,1,0)  2012-05-31 - 2014-09-23        1.169255
# 5    India_36  ARIMA(3,1,0)  2014-09-23 - 2023-06-07        1.108327
# 6    India_40  ARIMA(5,1,0)  2010-01-01 - 2013-01-04        1.027298
# 7    India_40  ARIMA(5,1,0)  2013-01-04 - 2021-04-15        0.939478
# 8    India_40  ARIMA(5,1,0)  2021-04-15 - 2024-01-18        1.028882
# 9    India_67  ARIMA(4,1,0)  2010-01-01 - 2012-05-30        0.983732
# 10   India_67  ARIMA(4,1,0)  2012-05-30 - 2020-03-10        1.000092
# 11   India_67  ARIMA(4,1,0)  2020-03-10 - 2024-01-18        1.069514
# 12   India_69  ARIMA(4,1,0)  2010-01-01 - 2012-01-23        0.988184
# ...

# %%
dfiiex.to_excel("IndiaIntEX20052024.xlsx")

# %%
with pd.ExcelWriter('All_metrics_vkr.xlsx') as writer:
    
    dfс.to_excel(writer, sheet_name='China')
    dfi.to_excel(writer, sheet_name='India') 
    
    dfcex.to_excel(writer, sheet_name='China_ex')
    dfiex.to_excel(writer, sheet_name='India_ex') 
    
    dfci.to_excel(writer, sheet_name='China_intevals')
    dfii.to_excel(writer, sheet_name='India_intevals') 
    
    dfciex.to_excel(writer, sheet_name='China_intevals_ex')
